# %% [markdown]
# # API Scavenger Game
#
# ## Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp.

# %%
# import libraries here
import requests
import pandas as pd
import json
from pandas.io.json import json_normalize

# %% [markdown]
# Assuming the main lab repo is ironhack-datalabs/madrid-oct-2018, you will:
#
# #### 1. Obtain the full list of forks created from the main lab repo via Github API.

# %% [markdown]
# To list forks, we can use the GET method. As explained in the GitHub API documentation, we need to make the request to: GET /repos/:owner/:repo/forks.

# %%
# your code here
username = 'Zak-ScorpiuS'
token = '241308738c5a63b963338cb64fe33b89afcf9a59'

reponse = requests.get('https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/forks', auth=(username,token))
print('reponse code ', reponse)
# Out:
# reponse code  <Response [200]>

# %%
result = reponse.json()
result
# Out:
# [{'id': 220066216,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMjAwNjYyMTY=',
#   'name': 'mad-oct-2018',
#   'full_name': 'ToniPons97/mad-oct-2018',
#   'private': False,
#   'owner': {'login': 'ToniPons97',
#    'id': 45130294,
#    'node_id': 'MDQ6VXNlcjQ1MTMwMjk0',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/45130294?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ToniPons97',
#    'html_url': 'https://github.com/ToniPons97',
#    'followers_url': 'https://api.github.com/users/ToniPons97/followers',
#    'following_url': 'https://api.github.com/users/ToniPons97/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ToniPons97/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ToniPons97/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ToniPons97/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ToniPons97/orgs',
# ...

# %%
print(json.dumps(result, indent=4))
# Out:
# [
#     {
#         "id": 220066216,
#         "node_id": "MDEwOlJlcG9zaXRvcnkyMjAwNjYyMTY=",
#         "name": "mad-oct-2018",
#         "full_name": "ToniPons97/mad-oct-2018",
#         "private": false,
#         "owner": {
#             "login": "ToniPons97",
#             "id": 45130294,
#             "node_id": "MDQ6VXNlcjQ1MTMwMjk0",
#             "avatar_url": "https://avatars3.githubusercontent.com/u/45130294?v=4",
#             "gravatar_id": "",
#             "url": "https://api.github.com/users/ToniPons97",
#             "html_url": "https://github.com/ToniPons97",
#             "followers_url": "https://api.github.com/users/ToniPons97/followers",
#             "following_url": "https://api.github.com/users/ToniPons97/following{/other_user}",
#             "gists_url": "https://api.github.com/users/ToniPons97/gists{/gist_id}",
#             "starred_url": "https://api.github.com/users/ToniPons97/starred{/owner}{/repo}",
# ...

# %%
result[0]['forks_url']
# Out:
# 'https://api.github.com/repos/ToniPons97/mad-oct-2018/forks'

# %%
len(result)
# Out:
# 16

# %%
for fork in result:
    print(fork['forks_url'])
# Out:
# https://api.github.com/repos/ToniPons97/mad-oct-2018/forks
# https://api.github.com/repos/rsennes/mad-oct-2018/forks
# https://api.github.com/repos/gggfaria/mad-oct-2018/forks
# https://api.github.com/repos/nancyulric/mad-oct-2018/forks
# https://api.github.com/repos/lmartinezruizit/datamad0119/forks
# https://api.github.com/repos/eye8/madrid-oct-2018/forks
# https://api.github.com/repos/ArieHassan/madrid-oct-2018/forks
# https://api.github.com/repos/cmvalma/madrid-oct-2018/forks
# https://api.github.com/repos/criraca/madrid-oct-2018/forks
# https://api.github.com/repos/boyander/madrid-oct-2018/forks
# https://api.github.com/repos/AlbertoCastellanos/madrid-oct-2018/forks
# https://api.github.com/repos/elenajpp/madrid-oct-2018/forks
# https://api.github.com/repos/pablobarrio/madrid-oct-2018/forks
# https://api.github.com/repos/miriammg/madrid-oct-2018/forks
# https://api.github.com/repos/albertogcmr/madrid-oct-2018/forks
# https://api.github.com/repos/marisfont/madrid-oct-2018/forks

# %% [markdown]
# #### 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
# Hint: Each language should appear only once in your array.
# Print the language array. It should be something like: ["Python", "Jupyter Notebook", "HTML"]

# %%
# your code here
print(result[0]['language'])
# Out:
# None

# %%
result[1]['language']
# Out:
# 'Jupyter Notebook'

# %%
languages = []
for language in result:
    languages.append(language['language'])
    
print(languages)
# Out:
# [None, 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'HTML', 'Jupyter Notebook', 'Jupyter Notebook', 'Python', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook']

# %%
cool_list = list(set(languages))
print(cool_list)
#in order to have them without repetition, here we go!
# Out:
# ['HTML', None, 'Jupyter Notebook', 'Python']

# %% [markdown]
# ## Challenge 2: Count Commits
# Count how many commits were made in the month of october of 2018.
# #### 1. Obtain all the commits made in October 2018 via API, which is a JSON array that contains multiple commit objects.

# %%
# your code here

reponse2 = requests.get('https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/commits', params={'page':2}, auth=(username,token))
print('reponse code ', reponse2)
# Out:
# reponse code  <Response [200]>

# %%
reponse2.json()
# Out:
# [{'sha': '46ebf45b02631c31185c8079010933fb03ccaf4f',
#   'node_id': 'MDY6Q29tbWl0MTUzNzIwODA0OjQ2ZWJmNDViMDI2MzFjMzExODVjODA3OTAxMDkzM2ZiMDNjY2FmNGY=',
#   'commit': {'author': {'name': 'Zhou Zhou',
#     'email': 'zhou.eye8@gmail.com',
#     'date': '2019-01-04T18:39:10Z'},
#    'committer': {'name': 'Zhou Zhou',
#     'email': 'zhou.eye8@gmail.com',
#     'date': '2019-01-04T18:39:10Z'},
#    'message': "Merge branch 'master' of https://github.com/ironhack-labs/data-labs",
#    'tree': {'sha': '84bdbcc944bac064e404471425c005ba374a4963',
#     'url': 'https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/git/trees/84bdbcc944bac064e404471425c005ba374a4963'},
#    'url': 'https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/git/commits/46ebf45b02631c31185c8079010933fb03ccaf4f',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
# ...

# %%
reponse2.headers
# Out:
# {'Date': 'Fri, 31 Jan 2020 16:14:31 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Server': 'GitHub.com', 'Status': '200 OK', 'X-RateLimit-Limit': '5000', 'X-RateLimit-Remaining': '4998', 'X-RateLimit-Reset': '1580490871', 'Cache-Control': 'private, max-age=60, s-maxage=60', 'Vary': 'Accept, Authorization, Cookie, X-GitHub-OTP, Accept-Encoding', 'ETag': 'W/"b7be045c54a79013e0ffeaa8f9b17de9"', 'Last-Modified': 'Mon, 19 Aug 2019 11:11:36 GMT', 'X-OAuth-Scopes': 'repo', 'X-Accepted-OAuth-Scopes': '', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/repositories/153720804/commits?page=2>; rel="next", <https://api.github.com/repositories/153720804/commits?page=11>; rel="last"', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type', 'Access-Control-
# ...

# %%
commits = reponse2.json()
commits
# Out:
# [{'sha': '1638e5506e6947b77bfe78761d345476ae80d017',
#   'node_id': 'MDY6Q29tbWl0MTUzNzIwODA0OjE2MzhlNTUwNmU2OTQ3Yjc3YmZlNzg3NjFkMzQ1NDc2YWU4MGQwMTc=',
#   'commit': {'author': {'name': 'Marc Pomar',
#     'email': 'marc@faable.com',
#     'date': '2019-08-19T11:11:36Z'},
#    'committer': {'name': 'Marc Pomar',
#     'email': 'marc@faable.com',
#     'date': '2019-08-19T11:11:36Z'},
#    'message': 'Cambiar los autores',
#    'tree': {'sha': '51812285dc70ac37103735ee7ed672befc582b5f',
#     'url': 'https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/git/trees/51812285dc70ac37103735ee7ed672befc582b5f'},
#    'url': 'https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/git/commits/1638e5506e6947b77bfe78761d345476ae80d017',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
# ...

# %%
print(json.dumps(commits, indent=4))
# Out:
# [
#     {
#         "sha": "1638e5506e6947b77bfe78761d345476ae80d017",
#         "node_id": "MDY6Q29tbWl0MTUzNzIwODA0OjE2MzhlNTUwNmU2OTQ3Yjc3YmZlNzg3NjFkMzQ1NDc2YWU4MGQwMTc=",
#         "commit": {
#             "author": {
#                 "name": "Marc Pomar",
#                 "email": "marc@faable.com",
#                 "date": "2019-08-19T11:11:36Z"
#             },
#             "committer": {
#                 "name": "Marc Pomar",
#                 "email": "marc@faable.com",
#                 "date": "2019-08-19T11:11:36Z"
#             },
#             "message": "Cambiar los autores",
#             "tree": {
#                 "sha": "51812285dc70ac37103735ee7ed672befc582b5f",
#                 "url": "https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/git/trees/51812285dc70ac37103735ee7ed672befc582b5f"
#             },
#             "url": "https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/git/commits/1638e5506e6947b77bfe78761d345476ae80d017",
# ...

# %%
print(json.dumps(commits[10]['commit'], indent=4))
# Out:
# {
#     "author": {
#         "name": "Zhou Zhou",
#         "email": "zhou.eye8@gmail.com",
#         "date": "2019-01-16T22:24:35Z"
#     },
#     "committer": {
#         "name": "Zhou Zhou",
#         "email": "zhou.eye8@gmail.com",
#         "date": "2019-01-16T22:24:35Z"
#     },
#     "message": "minor updates",
#     "tree": {
#         "sha": "cb1d28ea4a96adfd111cc8656523817acac07608",
#         "url": "https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/git/trees/cb1d28ea4a96adfd111cc8656523817acac07608"
#     },
#     "url": "https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/git/commits/ba93368ee5593b15c7b1829f82cbacb9a003476c",
#     "comment_count": 0,
#     "verification": {
#         "verified": false,
#         "reason": "unsigned",
#         "signature": null,
#         "payload": null
#     }
# }

# %%
len(commits)
# Out:
# 30

# %%
commits[10]
# Out:
# {'sha': 'ba93368ee5593b15c7b1829f82cbacb9a003476c',
#  'node_id': 'MDY6Q29tbWl0MTUzNzIwODA0OmJhOTMzNjhlZTU1OTNiMTVjN2IxODI5ZjgyY2JhY2I5YTAwMzQ3NmM=',
#  'commit': {'author': {'name': 'Zhou Zhou',
#    'email': 'zhou.eye8@gmail.com',
#    'date': '2019-01-16T22:24:35Z'},
#   'committer': {'name': 'Zhou Zhou',
#    'email': 'zhou.eye8@gmail.com',
#    'date': '2019-01-16T22:24:35Z'},
#   'message': 'minor updates',
#   'tree': {'sha': 'cb1d28ea4a96adfd111cc8656523817acac07608',
#    'url': 'https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/git/trees/cb1d28ea4a96adfd111cc8656523817acac07608'},
#   'url': 'https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/git/commits/ba93368ee5593b15c7b1829f82cbacb9a003476c',
#   'comment_count': 0,
#   'verification': {'verified': False,
#    'reason': 'unsigned',
#    'signature': None,
#    'payload': None}},
#  'url': 'https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/commits/ba93368ee5593b15c7b1829f82cbacb9a003476c',
# ...

# %%
commits[10]['commit']
# Out:
# {'author': {'name': 'Zhou Zhou',
#   'email': 'zhou.eye8@gmail.com',
#   'date': '2019-01-16T22:24:35Z'},
#  'committer': {'name': 'Zhou Zhou',
#   'email': 'zhou.eye8@gmail.com',
#   'date': '2019-01-16T22:24:35Z'},
#  'message': 'minor updates',
#  'tree': {'sha': 'cb1d28ea4a96adfd111cc8656523817acac07608',
#   'url': 'https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/git/trees/cb1d28ea4a96adfd111cc8656523817acac07608'},
#  'url': 'https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/git/commits/ba93368ee5593b15c7b1829f82cbacb9a003476c',
#  'comment_count': 0,
#  'verification': {'verified': False,
#   'reason': 'unsigned',
#   'signature': None,
#   'payload': None}}

# %%
len(commits[1]['commit'])
# Out:
# 7

# %%
commits[19]['commit']['author']['name']
# Out:
# 'Tony Ojeda'

# %%
commits[10]['commit']['author']['date']
# Out:
# '2019-01-16T22:24:35Z'

# %%
c_name_date = {}

for c in commits:
    c_name_date.update({c['commit']['author']['name']:c['commit']['author']['date']})

print(c_name_date)
# Out:
# {'Marc Pomar': '2019-08-19T11:11:36Z', 'ta-data-bcn': '2019-03-07T15:38:52Z', 'Tony Ojeda': '2019-01-07T15:15:49Z', 'Michal Monselise': '2019-01-05T02:20:54Z', 'Zhou Zhou': '2019-01-05T17:05:18Z'}

# %% [markdown]
# #### 2. Count how many commit objects are contained in the array.

# %%
# your code here
len(commits[1]['commit'])
# Out:
# 7

# %% [markdown]
# ## Challenge 3: Hidden Cold Joke
#
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain .scavengerhunt and they are scattered in different directories of this repo. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are scattered randomly throughout this repo. You need to search for these files by calling the Github API, not searching the local files on your computer.
#
# #### 1. Find the secret files.

# %%
# your code here
username = 'Zak-ScorpiuS'
token = '241308738c5a63b963338cb64fe33b89afcf9a59'
url = 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents'

reponse3 = requests.get(url, auth=(username,token))
print('reponse code ', reponse3)
# Out:
# reponse code  <Response [200]>

# %%
secrets = reponse3.json()
secrets
# Out:
# [{'name': '.gitignore',
#   'path': '.gitignore',
#   'sha': 'e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#   'size': 10,
#   'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master',
#   'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/master/.gitignore',
#   'git_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#   'download_url': 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/.gitignore',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master',
#    'git': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#    'html': 'https://github.com/ironhack-datalabs/scavenger/blob/master/.gitignore'}},
#  {'name': '15024',
#   'path': '15024',
#   'sha': '2945e51c87ad5da893c954afcf092f06343bbb7d',
#   'size': 0,
# ...

# %%
print(json.dumps(secrets, indent=4))
# Out:
# [
#     {
#         "name": ".gitignore",
#         "path": ".gitignore",
#         "sha": "e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf",
#         "size": 10,
#         "url": "https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master",
#         "html_url": "https://github.com/ironhack-datalabs/scavenger/blob/master/.gitignore",
#         "git_url": "https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf",
#         "download_url": "https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/.gitignore",
#         "type": "file",
#         "_links": {
#             "self": "https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master",
#             "git": "https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf",
#             "html": "https://github.com/ironhack-datalabs/scavenger/blob/master/.gitignore"
# ...

# %%
secrets[1]['name']
# Out:
# '15024'

# %%
contents = []
for elem in secrets:
    contents.append(elem['name'])

contents.pop(0)
print(contents)
# Out:
# ['15024', '15534', '17020', '30351', '40303', '44639', '45525', '47222', '47830', '49418', '50896', '55417', '55685', '60224', '64880', '66032', '68848', '70751', '70985', '88596', '89046', '89338', '91701', '97881', '98750']

# %%
int(contents[0])
# Out:
# 15024

# %%
contents_int = []
for elem in contents:
    contents_int.append(int(elem))

print(contents_int)
# Out:
# [15024, 15534, 17020, 30351, 40303, 44639, 45525, 47222, 47830, 49418, 50896, 55417, 55685, 60224, 64880, 66032, 68848, 70751, 70985, 88596, 89046, 89338, 91701, 97881, 98750]

# %%
username = 'Zak-ScorpiuS'
token = '241308738c5a63b963338cb64fe33b89afcf9a59'
url = 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/'
findings_folder = []
for num in contents_int:
    xy = requests.get(f'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/{num}', auth=(username,token))
    findings_folder.append(xy.json())
    
findings_folder
# Out:
# [[{'name': '.0006.scavengerhunt',
#    'path': '15024/.0006.scavengerhunt',
#    'sha': '1c9064284a24b3486015eafdb391b141c27ada2b',
#    'size': 3,
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt?ref=master',
#    'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/master/15024/.0006.scavengerhunt',
#    'git_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#    'download_url': 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0006.scavengerhunt',
#    'type': 'file',
#    '_links': {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt?ref=master',
#     'git': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#     'html': 'https://github.com/ironhack-datalabs/scavenger/blob/master/15024/.0006.scavengerhunt'}},
# ...

# %%
xy = requests.get(f'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15534', auth=(username,token))
xy.json()
# Out:
# [{'name': '.0008.scavengerhunt',
#   'path': '15534/.0008.scavengerhunt',
#   'sha': 'e351fb73264581ce26504b97ef07daea35116f32',
#   'size': 6,
#   'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15534/.0008.scavengerhunt?ref=master',
#   'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/master/15534/.0008.scavengerhunt',
#   'git_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e351fb73264581ce26504b97ef07daea35116f32',
#   'download_url': 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15534/.0008.scavengerhunt',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15534/.0008.scavengerhunt?ref=master',
#    'git': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e351fb73264581ce26504b97ef07daea35116f32',
#    'html': 'https://github.com/ironhack-datalabs/scavenger/blob/master/15534/.0008.scavengerhunt'}},
# ...

# %%
username = 'Zak-ScorpiuS'
token = '241308738c5a63b963338cb64fe33b89afcf9a59'
url = 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/'
findings_folder = []
for num in contents_int:
    print(num)
    xy = requests.get(f'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/{num}', auth=(username,token)).json()
    for dic in xy:
        if 'scavenger' in dic['html_url']:
            findings_folder.append(dic['html_url'])
    
findings_folder
# Out:
# 15024
# 15534
# 17020
# 30351
# 40303
# 44639
# 45525
# 47222
# 47830
# 49418
# 50896
# 55417
# 55685
# 60224
# 64880
# 66032
# 68848
# 70751
# 70985
# 88596
# 89046
# 89338
# 91701
# 97881
# 98750
# ['https://github.com/ironhack-datalabs/scavenger/blob/master/15024/.0006.scavengerhunt',
#  'https://github.com/ironhack-datalabs/scavenger/blob/master/15024/40',
#  'https://github.com/ironhack-datalabs/scavenger/blob/master/15024/74',
#  'https://github.com/ironhack-datalabs/scavenger/blob/master/15024/99',
#  'https://github.com/ironhack-datalabs/scavenger/blob/master/15534/.0008.scavengerhunt',
#  'https://github.com/ironhack-datalabs/scavenger/blob/master/15534/.0012.scavengerhunt',
#  'https://github.com/ironhack-datalabs/scavenger/blob/master/15534/2',
#  'https://github.com/ironhack-datalabs/scavenger/blob/master/15534/98',
#  'https://github.com/ironhack-datalabs/scavenger/blob/master/17020/.0007.scavengerhunt',
# ...

# %%
a = [i for i in findings_folder if i.endswith('hunt')]
a
# Out:
# ['https://github.com/ironhack-datalabs/scavenger/blob/master/15024/.0006.scavengerhunt',
#  'https://github.com/ironhack-datalabs/scavenger/blob/master/15534/.0008.scavengerhunt',
#  'https://github.com/ironhack-datalabs/scavenger/blob/master/15534/.0012.scavengerhunt',
#  'https://github.com/ironhack-datalabs/scavenger/blob/master/17020/.0007.scavengerhunt',
#  'https://github.com/ironhack-datalabs/scavenger/blob/master/30351/.0021.scavengerhunt',
#  'https://github.com/ironhack-datalabs/scavenger/blob/master/40303/.0022.scavengerhunt',
#  'https://github.com/ironhack-datalabs/scavenger/blob/master/44639/.0005.scavengerhunt',
#  'https://github.com/ironhack-datalabs/scavenger/blob/master/45525/.0018.scavengerhunt',
#  'https://github.com/ironhack-datalabs/scavenger/blob/master/47222/.0016.scavengerhunt',
#  'https://github.com/ironhack-datalabs/scavenger/blob/master/47222/.0024.scavengerhunt',
# ...

# %%
findings_folder
# Out:
# [[{'name': '.0006.scavengerhunt',
#    'path': '15024/.0006.scavengerhunt',
#    'sha': '1c9064284a24b3486015eafdb391b141c27ada2b',
#    'size': 3,
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt?ref=master',
#    'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/master/15024/.0006.scavengerhunt',
#    'git_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#    'download_url': 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0006.scavengerhunt',
#    'type': 'file',
#    '_links': {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt?ref=master',
#     'git': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#     'html': 'https://github.com/ironhack-datalabs/scavenger/blob/master/15024/.0006.scavengerhunt'}},
# ...

# %%
dictionary = {}
sorted_dict = {}
for i in range(30):
    if findings_folder[i][0]["name"].endswith('.scavengerhunt'):
        dictionary[findings_folder[i][0]["name"]] = findings_folder[i][0]["path"]
for i in sorted(dictionary):
    sorted_dict[i] = dictionary[i]
sorted_dict
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-127-0cbaac4e681d> in <module>
#       2 sorted_dict = {}
#       3 for i in range(30):
# ----> 4     if findings_folder[i][0]["name"].endswith('.scavengerhunt'):
#       5         dictionary[findings_folder[i][0]["name"]] = findings_folder[i][0]["path"]
#       6 for i in sorted(dictionary):
#
# KeyError: 0

# %%
dictionary = {}
sorted_dict = {}
for i in range(25):
    if findings_folder[i][0]["name"].endswith('.scavengerhunt'):
        dictionary[findings_folder[i][0]["name"]] = findings_folder[i][0]["path"]
for i in sorted(dictionary):
    sorted_dict[i] = dictionary[i]
sorted_dict
# Out:
# {'.0001.scavengerhunt': '98750/.0001.scavengerhunt',
#  '.0002.scavengerhunt': '88596/.0002.scavengerhunt',
#  '.0003.scavengerhunt': '60224/.0003.scavengerhunt',
#  '.0004.scavengerhunt': '68848/.0004.scavengerhunt',
#  '.0005.scavengerhunt': '44639/.0005.scavengerhunt',
#  '.0006.scavengerhunt': '15024/.0006.scavengerhunt',
#  '.0007.scavengerhunt': '17020/.0007.scavengerhunt',
#  '.0008.scavengerhunt': '15534/.0008.scavengerhunt',
#  '.0009.scavengerhunt': '97881/.0009.scavengerhunt',
#  '.0010.scavengerhunt': '47830/.0010.scavengerhunt',
#  '.0011.scavengerhunt': '50896/.0011.scavengerhunt',
#  '.0013.scavengerhunt': '89338/.0013.scavengerhunt',
#  '.0014.scavengerhunt': '49418/.0014.scavengerhunt',
#  '.0015.scavengerhunt': '91701/.0015.scavengerhunt',
#  '.0016.scavengerhunt': '47222/.0016.scavengerhunt',
#  '.0017.scavengerhunt': '70985/.0017.scavengerhunt',
#  '.0018.scavengerhunt': '45525/.0018.scavengerhunt',
#  '.0019.scavengerhunt': '70751/.0019.scavengerhunt',
# ...

# %% [markdown]
# #### 2.  Sort the filenames ascendingly.

# %%
# your code here
final_list = []
for k,v in sorted_dict.items():
    final_list.append(v)
final_list
# Out:
# ['98750/.0001.scavengerhunt',
#  '88596/.0002.scavengerhunt',
#  '60224/.0003.scavengerhunt',
#  '68848/.0004.scavengerhunt',
#  '44639/.0005.scavengerhunt',
#  '15024/.0006.scavengerhunt',
#  '17020/.0007.scavengerhunt',
#  '15534/.0008.scavengerhunt',
#  '97881/.0009.scavengerhunt',
#  '47830/.0010.scavengerhunt',
#  '50896/.0011.scavengerhunt',
#  '89338/.0013.scavengerhunt',
#  '49418/.0014.scavengerhunt',
#  '91701/.0015.scavengerhunt',
#  '47222/.0016.scavengerhunt',
#  '70985/.0017.scavengerhunt',
#  '45525/.0018.scavengerhunt',
#  '70751/.0019.scavengerhunt',
#  '55685/.0020.scavengerhunt',
#  '30351/.0021.scavengerhunt',
#  '40303/.0022.scavengerhunt',
#  '55417/.0023.scavengerhunt']

# %% [markdown]
# #### 3. Read the content of each secret files into an array of strings.
# Since the response is encoded, you will need to send the following information in the header of your request:
# ````python
# headers = {'Accept': 'application/vnd.github.v3.raw'}
# ````

# %%
# your code here
headers = {'Accept': 'application/vnd.github.v3.raw'}

get_files = []
for f in final_list:
    a= requests.get(f'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/{f}', headers=headers)
    get_files.append(a.text)

get_files
# Out:
# ['In\n',
#  'data\n',
#  'science,\n',
#  '80\n',
#  'percent\n',
#  'of\n',
#  'time\n',
#  'spent\n',
#  'is\n',
#  'preparing\n',
#  'data,\n',
#  'percent\n',
#  'of\n',
#  'time\n',
#  'is\n',
#  'spent\n',
#  'complaining\n',
#  'about\n',
#  'the\n',
#  'need\n',
#  'to\n',
#  'prepare\n']

# %% [markdown]
# #### 4. Concatenate the strings in the array separating each two with a whitespace.

# %%
len(clean)
# Out:
# 22

# %%
# your code here
clean = []

for get in get_files:
    zzz = get.replace('\n', '')
    clean.append(zzz)
    
clean
# Out:
# ['In',
#  'data',
#  'science,',
#  '80',
#  'percent',
#  'of',
#  'time',
#  'spent',
#  'is',
#  'preparing',
#  'data,',
#  'percent',
#  'of',
#  'time',
#  'is',
#  'spent',
#  'complaining',
#  'about',
#  'the',
#  'need',
#  'to',
#  'prepare']

# %% [markdown]
# #### 5. Print out the joke.

# %%
# your code here
print(clean)
# Out:
# ['In', 'data', 'science,', '80', 'percent', 'of', 'time', 'spent', 'is', 'preparing', 'data,', 'percent', 'of', 'time', 'is', 'spent', 'complaining', 'about', 'the', 'need', 'to', 'prepare']

# %%
joke = " ".join(clean) + "."
joke
# Out:
# 'In data science, 80 percent of time spent is preparing data, percent of time is spent complaining about the need to prepare.'
